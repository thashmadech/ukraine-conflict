# %% [markdown]
# <a href="https://colab.research.google.com/github/thashmadech/ukraine-conflict/blob/main/Ukraine_conflict_Viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns

# %%
human_loss = pd.read_csv('https://github.com/thashmadech/ukraine-conflict/blob/main/russia_losses_personnel.csv?raw=True')
equipment_loss=pd.read_csv('https://github.com/thashmadech/ukraine-conflict/blob/main/russia_losses_equipment.csv?raw=True')

# %%
human_loss.head()
# Out:
#          date  day  personnel    POW personnel*
# 0  2022-02-26    3       4300    NaN        NaN
# 1  2022-02-28    5       5300    NaN        NaN
# 2  2022-03-01    6       5710  200.0        NaN
# 3  2022-03-02    7       5840    NaN        NaN
# 4  2022-03-03    8       9000    NaN        NaN

# %%
equipment_loss.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  BUK  \
# 0  2022-02-26    3        27          26   146  706               49    1
# 1  2022-02-28    5        29          29   150  816               74    1
# 2  2022-03-01    6        29          29   198  846               77    1
# 3  2022-03-02    7        30          31   211  862               85    1
# 4  2022-03-03    8        30          31   217  900               90    1
#
#    MRL  military auto  fuel tank  drone  naval ship  anti-aircraft warfare
# 0    4             30         60      2           2                      0
# 1   21            291         60      3           2                      5
# 2   24            305         60      3           2                      7
# 3   40            355         60      3           2                      9
# 4   42            374         60      3           2                     11

# %%
figure(figsize=(8, 6), dpi=80)
plt.xticks(rotation=45)
plt.bar(human_loss['date'],human_loss['personnel'])
plt.plot(human_loss['date'],human_loss['personnel'], color="r",linestyle="--",linewidth=3)
